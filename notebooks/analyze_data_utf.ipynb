# %%
from pathlib import Path
data_dir = Path("amazigh_data")
[l for l in data_dir.glob("**/*.png")]
# Out:
# [PosixPath('amazigh_data/chars/char_7692.png'),
#  PosixPath('amazigh_data/chars/char_7693.png'),
#  PosixPath('amazigh_data/chars/char_611.png'),
#  PosixPath('amazigh_data/chars/char_7779.png'),
#  PosixPath('amazigh_data/chars/char_7778.png'),
#  PosixPath('amazigh_data/chars/char_404.png'),
#  PosixPath('amazigh_data/chars/char_603.png'),
#  PosixPath('amazigh_data/chars/char_400.png'),
#  PosixPath('amazigh_data/chars/char_7770.png'),
#  PosixPath('amazigh_data/chars/char_7771.png'),
#  PosixPath('amazigh_data/chars/char_7789.png'),
#  PosixPath('amazigh_data/chars/char_7788.png'),
#  PosixPath('amazigh_data/chars/char_7826.png'),
#  PosixPath('amazigh_data/chars/char_7827.png'),
#  PosixPath('amazigh_data/chars/char_486.png'),
#  PosixPath('amazigh_data/chars/char_487.png'),
#  PosixPath('amazigh_data/chars/char_268.png'),
#  PosixPath('amazigh_data/chars/char_269.png'),
#  PosixPath('amazigh_data/chars/char_7716.png'),
#  PosixPath('amazigh_data/chars/char_7717.png'),
# ...
